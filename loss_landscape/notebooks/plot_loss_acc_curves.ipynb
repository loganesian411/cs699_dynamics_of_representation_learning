# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read in test accuracy results
# acc_test = pd.read_csv('./results/acc/run-resnet20_skip_bn_bias-tag-test_acc.csv')
# acc_test_adam = pd.read_csv('./results/acc/run-resnet20_skip_bn_bias_adam-tag-test_acc.csv')
# acc_test_5 = pd.read_csv('./results/acc/run-resnet20_skip_bn_bias_labelnoise5-tag-test_acc.csv')
# acc_test_15 = pd.read_csv('./results/acc/run-resnet20_skip_bn_bias_labelnoise15-tag-test_acc.csv')
# acc_test_25 = pd.read_csv('./results/acc/run-resnet20_skip_bn_bias_labelnoise25-tag-test_acc.csv')
# acc_test_50 = pd.read_csv('./results/acc/run-resnet20_skip_bn_bias_labelnoise50-tag-test_acc.csv')

acc_test = pd.read_csv('./../results/acc/run-resnet20_skip_bn_bias-tag-test_acc.csv')
acc_test_wo_skip = pd.read_csv('./../results/acc/run-resnet20_btch128_skip_bn_bias_remove_skip_connections-tag-test_acc.csv')
acc_test_base = pd.read_csv('./../results/acc/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_v2-tag-test_acc.csv')
acc_test_1em1 = pd.read_csv('./../results/acc/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_rndnoise_.1-tag-test_acc.csv')
acc_test_1em0 = pd.read_csv('./../results/acc/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_rndnoise_1-tag-test_acc.csv')
acc_test_30per = pd.read_csv('./../results/acc/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_drop_.3-tag-test_acc.csv')
acc_test_50per = pd.read_csv('./../results/acc/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_drop_.5-tag-test_acc.csv')

#Read in test loss results
# loss_test = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias-tag-test_loss.csv')
# loss_test_adam = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_adam-tag-test_loss.csv')
# loss_test_5 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise5-tag-test_loss.csv')
# loss_test_15 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise15-tag-test_loss.csv')
# loss_test_25 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise25-tag-test_loss.csv')
# loss_test_50 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise50-tag-test_loss.csv')

loss_test = pd.read_csv('./../results/loss/run-resnet20_skip_bn_bias-tag-test_loss.csv')
loss_test_wo_skip = pd.read_csv('./../results/loss/run-resnet20_btch128_skip_bn_bias_remove_skip_connections-tag-test_loss.csv')
loss_test_base = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_v2-tag-test_loss.csv')
loss_test_1em1 = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_rndnoise_.1-tag-test_loss.csv')
loss_test_1em0 = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_rndnoise_1-tag-test_loss.csv')
loss_test_30per = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_drop_.3-tag-test_loss.csv')
loss_test_50per = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_drop_.5-tag-test_loss.csv')

# Read in train loss results
# loss_train = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias-tag-train_loss.csv')
# loss_train_adam = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_adam-tag-train_loss.csv')
# loss_train_5 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise5-tag-train_loss.csv')
# loss_train_15 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise15-tag-train_loss.csv')
# loss_train_25 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise25-tag-train_loss.csv')
# loss_train_50 = pd.read_csv('./results/loss/run-resnet20_skip_bn_bias_labelnoise50-tag-train_loss.csv')

loss_train = pd.read_csv('./../results/loss/run-resnet20_skip_bn_bias-tag-train_loss.csv')
loss_train_wo_skip = pd.read_csv('./../results/loss/run-resnet20_btch128_skip_bn_bias_remove_skip_connections-tag-train_loss.csv')
loss_train_base = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_v2-tag-train_loss.csv')
loss_train_1em1 = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_rndnoise_.1-tag-train_loss.csv')
loss_train_1em0 = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_rndnoise_1-tag-train_loss.csv')
loss_train_30per = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_drop_.3-tag-train_loss.csv')
loss_train_50per = pd.read_csv('./../results/loss/run-resnet20_btch64_skip_bn_bias_remove_skip_connections_drop_.5-tag-train_loss.csv')


# train loss is higher res --> downsample
# loss_train = loss_train.iloc[::5, :]
# loss_train.reset_index(drop=True, inplace=True)
# loss_train_adam = loss_train_adam.iloc[::5, :]
# loss_train_adam.reset_index(drop=True, inplace=True)
# loss_train_5 = loss_train_5.iloc[::5, :]
# loss_train_5.reset_index(drop=True, inplace=True)
# loss_train_15 = loss_train_15.iloc[::5, :]
# loss_train_15.reset_index(drop=True, inplace=True)
# loss_train_25 = loss_train_25.iloc[::5, :]
# loss_train_25.reset_index(drop=True, inplace=True)
# loss_train_50 = loss_train_50.iloc[::5, :]
# loss_train_50.reset_index(drop=True, inplace=True)

# loss_train = loss_train.iloc[::5, :]
# loss_train.reset_index(drop=True, inplace=True)

# loss_train_wo_skip = loss_train_wo_skip.iloc[::5, :]
# loss_train_wo_skip.reset_index(drop=True, inplace=True)

# loss_train_1em1 = loss_train_1em1.iloc[::5, :]
# loss_train_1em1.reset_index(drop=True, inplace=True)

# loss_train_1em0 = loss_train_1em0.iloc[::5, :]
# loss_train_1em0.reset_index(drop=True, inplace=True)

# loss_train_30per = loss_train_25.iloc[::5, :]
# loss_train_30per.reset_index(drop=True, inplace=True)

# loss_train_50per = loss_train_50per.iloc[::5, :]
# loss_train_50per.reset_index(drop=True, inplace=True)

# %%
fig, axs = plt.subplots(1, 3,  figsize=(16, 4))


# axs[0].plot(loss_train["Value"], label="SGD + Momentum")
# axs[0].plot(loss_train_adam["Value"],label="Adam")
# axs[0].set_yticks(np.arange(0, 1.8, 0.25))
# axs[0].legend(fontsize=12)
# axs[0].set_xlabel('Epoch', fontsize=16)
# axs[0].set_ylabel('Loss', fontsize=16)
# axs[0].set_title('Training Loss',  fontsize=16)
# axs[0].grid()
# axs[0].tick_params(axis='both', which='major', labelsize=14)

axs[0].plot(loss_train["Value"], label="Skip connections")
axs[0].plot(loss_train_wo_skip["Value"],label="No skip connections")
axs[0].set_yticks(np.arange(0, 1.8, 0.25))
axs[0].legend(fontsize=12)
axs[0].set_xlabel('Time [Steps]', fontsize=16)
axs[0].set_ylabel('Loss', fontsize=16)
axs[0].set_title('Training Loss',  fontsize=16)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=14)



# axs[1].plot(loss_test["Value"], label="SGD + Momentum")
# axs[1].plot(loss_test_adam["Value"], label="Adam")
# axs[1].set_yticks(np.arange(0, 1.8, 0.25))
# axs[1].legend(fontsize=12)
# axs[1].set_xlabel('Epoch', fontsize=16)
# axs[1].set_ylabel('Loss', fontsize=16)
# axs[1].set_title('Test Loss',  fontsize=16)
# axs[1].grid()
# axs[1].tick_params(axis='both', which='major', labelsize=14)

axs[1].plot(loss_test["Value"], label="Skip connections")
axs[1].plot(loss_test_wo_skip["Value"], label="No skip connections")
axs[1].set_yticks(np.arange(0, 1.8, 0.25))
axs[1].legend(fontsize=12)
axs[1].set_xlabel('Time [Steps]', fontsize=16)
axs[1].set_ylabel('Loss', fontsize=16)
axs[1].set_title('Test Loss',  fontsize=16)
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=14)




# axs[2].plot(acc_test["Value"], label="SGD + Momentum")
# axs[2].plot(acc_test_adam["Value"], label="Adam")
# plt.ylim(0, 1)
# axs[2].legend(fontsize=12)
# axs[2].set_xlabel('Epoch', fontsize=16)
# axs[2].set_ylabel('Accuracy', fontsize=16)
# axs[2].set_title('Test Accuracy',  fontsize=16)
# axs[2].grid()
# axs[2].tick_params(axis='both', which='major', labelsize=14)

axs[2].plot(acc_test["Value"], label="Skip connections")
axs[2].plot(acc_test_wo_skip["Value"], label="No skip connections")
plt.ylim(0, 1)
axs[2].legend(fontsize=12)
axs[2].set_xlabel('Time [Steps]', fontsize=16)
axs[2].set_ylabel('Accuracy', fontsize=16)
axs[2].set_title('Test Accuracy',  fontsize=16)
axs[2].grid()
axs[2].tick_params(axis='both', which='major', labelsize=14)



fig.tight_layout(pad=1)
plt.savefig('./../results/loss_acc_figures/skip_connections.png', bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 3,  figsize=(16, 4))

axs[0].plot(loss_train_base["Value"], label="Batch 64")
axs[0].plot(loss_train_wo_skip["Value"],label="Batch 128")
axs[0].set_yticks(np.arange(0, 1.8, 0.25))
axs[0].legend(fontsize=12)
axs[0].set_xlabel('Time [Steps]', fontsize=16)
axs[0].set_ylabel('Loss', fontsize=16)
axs[0].set_title('Training Loss',  fontsize=16)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=14)


axs[1].plot(loss_test_base["Value"], label="Batch 64")
axs[1].plot(loss_test_wo_skip["Value"], label="Batch 128")
axs[1].set_yticks(np.arange(0, 1.8, 0.25))
axs[1].legend(fontsize=12)
axs[1].set_xlabel('Time [Steps]', fontsize=16)
axs[1].set_ylabel('Loss', fontsize=16)
axs[1].set_title('Test Loss',  fontsize=16)
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=14)


axs[2].plot(acc_test_base["Value"], label="Batch 64")
axs[2].plot(acc_test_wo_skip["Value"], label="Batch 128")
plt.ylim(0, 1)
axs[2].legend(fontsize=12)
axs[2].set_xlabel('Time [Steps]', fontsize=16)
axs[2].set_ylabel('Accuracy', fontsize=16)
axs[2].set_title('Test Accuracy',  fontsize=16)
axs[2].grid()
axs[2].tick_params(axis='both', which='major', labelsize=14)



fig.tight_layout(pad=1)
plt.savefig('./../results/loss_acc_figures/batch_sizes.png', bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 3,  figsize=(16, 4))
axs[0].plot(loss_train_base["Value"],label="baseline")
axs[0].plot(loss_train_1em1["Value"],label="0.1 std dev")
axs[0].plot(loss_train_1em0["Value"],label="1 std dev")




axs[0].set_yticks(np.arange(0, 2.5, 0.25))
axs[0].legend(fontsize=12)
axs[0].set_xlabel('Time [Steps]', fontsize=16)
axs[0].set_ylabel('Loss', fontsize=16)
axs[0].set_title('Training Loss',  fontsize=16)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=14)



axs[1].plot(loss_test_base["Value"], label="baseline")
axs[1].plot(loss_test_1em1["Value"], label="0.1 std dev")
axs[1].plot(loss_test_1em0["Value"], label="1 std dev")




axs[1].set_yticks(np.arange(0, 2.5, 0.25))
axs[1].legend(fontsize=12)
axs[1].set_xlabel('Time [Steps]', fontsize=16)
axs[1].set_ylabel('Loss', fontsize=16)
axs[1].set_title('Test Loss',  fontsize=16)
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=14)



axs[2].plot(acc_test_base["Value"], label="baseline")
axs[2].plot(acc_test_1em1["Value"], label="0.1 std dev")
axs[2].plot(acc_test_1em0["Value"], label="1 std dev")




plt.ylim(0.35, 0.95)
axs[2].legend(fontsize=12)
axs[2].set_xlabel('Time [Steps]', fontsize=16)
axs[2].set_ylabel('Accuracy', fontsize=16)
axs[2].set_title('Test Accuracy',  fontsize=16)
axs[2].grid()
axs[2].tick_params(axis='both', which='major', labelsize=14)



fig.tight_layout(pad=1)
plt.savefig('./../results/loss_acc_figures/noisy_pics.png', bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 3,  figsize=(16, 4))
axs[0].plot(loss_train_base["Value"],label="baseline")
axs[0].plot(loss_train_30per["Value"],label="30% drop")
axs[0].plot(loss_train_50per["Value"],label="50% drop")




axs[0].set_yticks(np.arange(0, 2.5, 0.25))
axs[0].legend(fontsize=12)
axs[0].set_xlabel('Time [Steps]', fontsize=16)
axs[0].set_ylabel('Loss', fontsize=16)
axs[0].set_title('Training Loss',  fontsize=16)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=14)



axs[1].plot(loss_test_base["Value"], label="baseline")
axs[1].plot(loss_test_30per["Value"], label="30% drop")
axs[1].plot(loss_test_50per["Value"], label="50% drop")




axs[1].set_yticks(np.arange(0, 2.5, 0.25))
axs[1].legend(fontsize=12)
axs[1].set_xlabel('Time [Steps]', fontsize=16)
axs[1].set_ylabel('Loss', fontsize=16)
axs[1].set_title('Test Loss',  fontsize=16)
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=14)



axs[2].plot(acc_test_base["Value"], label="baseline")
axs[2].plot(acc_test_30per["Value"], label="30% drop")
axs[2].plot(acc_test_50per["Value"], label="50% drop")




plt.ylim(0.35, 0.95)
axs[2].legend(fontsize=12)
axs[2].set_xlabel('Time [Steps]', fontsize=16)
axs[2].set_ylabel('Accuracy', fontsize=16)
axs[2].set_title('Test Accuracy',  fontsize=16)
axs[2].grid()
axs[2].tick_params(axis='both', which='major', labelsize=14)



fig.tight_layout(pad=1)
plt.savefig('./../results/loss_acc_figures/dropped_pixels.png', bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 3,  figsize=(16, 4))
axs[0].plot(loss_train_50["Value"],label="50%")
axs[0].plot(loss_train_25["Value"],label="25%")
axs[0].plot(loss_train_15["Value"],label="15%")
axs[0].plot(loss_train_5["Value"],label="5%")
axs[0].plot(loss_train["Value"], label="0%")




axs[0].set_yticks(np.arange(0, 2.5, 0.25))
axs[0].legend(fontsize=12)
axs[0].set_xlabel('Epoch', fontsize=16)
axs[0].set_ylabel('Loss', fontsize=16)
axs[0].set_title('Training Loss',  fontsize=16)
axs[0].grid()
axs[0].tick_params(axis='both', which='major', labelsize=14)



axs[1].plot(loss_test_50["Value"], label="50%")
axs[1].plot(loss_test_25["Value"], label="25%")
axs[1].plot(loss_test_15["Value"], label="15%")
axs[1].plot(loss_test_5["Value"], label="5%")
axs[1].plot(loss_test["Value"], label="0%")




axs[1].set_yticks(np.arange(0, 2.5, 0.25))
axs[1].legend(fontsize=12)
axs[1].set_xlabel('Epoch', fontsize=16)
axs[1].set_ylabel('Loss', fontsize=16)
axs[1].set_title('Test Loss',  fontsize=16)
axs[1].grid()
axs[1].tick_params(axis='both', which='major', labelsize=14)



axs[2].plot(acc_test_50["Value"], label="50%")
axs[2].plot(acc_test_25["Value"], label="25%")
axs[2].plot(acc_test_15["Value"], label="15%")
axs[2].plot(acc_test_5["Value"], label="5%")
axs[2].plot(acc_test["Value"], label="0%")




plt.ylim(0.35, 0.95)
axs[2].legend(fontsize=12)
axs[2].set_xlabel('Epoch', fontsize=16)
axs[2].set_ylabel('Accuracy', fontsize=16)
axs[2].set_title('Test Accuracy',  fontsize=16)
axs[2].grid()
axs[2].tick_params(axis='both', which='major', labelsize=14)



fig.tight_layout(pad=1)
plt.savefig('./figures/noisylabels.png', bbox_inches='tight')

# %%
fig, axs = plt.subplots()
axs.plot(acc_test["Value"], label="0%")
axs.plot(acc_test_5["Value"], label="5%")
axs.plot(acc_test_15["Value"], label="15%")
axs.plot(acc_test_25["Value"], label="25%")
axs.plot(acc_test_50["Value"], label="50%")
plt.ylim(0.9, 0.941)
axs.legend(fontsize=12)
axs.set_xlabel('Epoch', fontsize=16)
axs.set_ylabel('Accuracy', fontsize=16)
axs.set_title('Test Accuracy',  fontsize=16)
axs.grid()
axs.tick_params(axis='both', which='major', labelsize=14)
